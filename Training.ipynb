# %%
# Set the PYTHONPATH using the %env magic
# %env PYTHONPATH=/home/rwhite/NFS/Blake/PEEKxYOLO:$PYTHONPATH

# Run the training command
# !python yolov5/train.py --img 640 --batch 16 --epochs 50 --data satellite_components-71/data.yaml --cfg yolov5/models/yolov5s.yaml --weights ""
# Out:
# env: PYTHONPATH=/home/rwhite/NFS/Blake/PEEKxYOLO:$PYTHONPATH
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: rtw. Use `wandb login --relogin` to force relogin
# ...

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="FHbvEDIv2qI58CSqb9UD")
# project = rf.workspace("forairoboflow-gmail-com").project("satellite_components")
# version = project.version(71)
# dataset = version.download("yolov5")

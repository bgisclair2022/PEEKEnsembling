# %% [raw]
# @article{solovyev2021weighted,
#   title={Weighted boxes fusion: Ensembling boxes from different object detection models},
#   author={Solovyev, Roman and Wang, Weimin and Gabruseva, Tatiana},
#   journal={Image and Vision Computing},
#   pages={1-6},
#   year={2021},
#   publisher={Elsevier}
# }

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting ensemble-boxes
#   Downloading ensemble_boxes-1.0.9-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy in /home/rwhite/mambaforge/envs/notebook_env/lib/python3.10/site-packages (from ensemble-boxes) (1.23.5)
# Requirement already satisfied: numba in /home/rwhite/mambaforge/envs/notebook_env/lib/python3.10/site-packages (from ensemble-boxes) (0.59.1)
# Requirement already satisfied: pandas in /home/rwhite/mambaforge/envs/notebook_env/lib/python3.10/site-packages (from ensemble-boxes) (2.1.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/rwhite/mambaforge/envs/notebook_env/lib/python3.10/site-packages (from numba->ensemble-boxes) (0.42.0)
# Requirement already satisfied: tzdata>=2022.1 in /home/rwhite/mambaforge/envs/notebook_env/lib/python3.10/site-packages (from pandas->ensemble-boxes) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/rwhite/mambaforge/envs/notebook_env/lib/python3.10/site-packages (from pandas->ensemble-boxes) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/rwhite/mambaforge/envs/notebook_env/lib/python3.10/site-packages (from pandas->ensemble-boxes) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/rwhite/mambaforge/envs/notebook_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->ensemble-boxes) (1.16.0)
# Installing collected packages: ensemble-boxes
# Successfully installed ensemble-boxes-1.0.9
# Note: you may need to restart the kernel to use updated packages.
